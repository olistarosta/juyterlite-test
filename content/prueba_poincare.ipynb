# %%
from poincare import System, Variable, initial

class Model(System):
    x:Variable = initial(1)

    eq = x.derive() << 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from poincare import System, Variable, initial
# ----> 3 class Model(System):
#       4     x:Variable = initial(1)
#       6     eq = x.derive() << 1
#
# Cell In[2], line 4, in Model()
#       3 class Model(System):
# ----> 4     x:Variable = initial(1)
#       6     eq = x.derive() << 1
#
# TypeError: initial() takes 0 positional arguments but 1 was given
